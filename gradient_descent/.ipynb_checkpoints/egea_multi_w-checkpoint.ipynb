# %%
pwd
# Out:
# 'C:\\Users\\emr_f\\Desktop\\veri madenciliği\\çalışmalar\\gradient_descent'

# %%
import numpy as np
import pandas as pd

# %%
veri= pd.read_excel("egea_fiyatlar.xlsx",1)
veri_np= veri.to_numpy()
veri.head()
# Out:
#    yaş  km (bin)  fiyat (bin tl)
# 0    4       120             825
# 1    1        50             982
# 2    4        98             795
# 3    3        61             805
# 4    3       105             689

# %%
veri_float= veri_np[:,:-1].astype(float)
veri_norm= veri_float

for j in range(veri_float.shape[1]):
    max= veri_float[:,j].max()
    min= veri_float[:,j].min()
    maxmin_fark= max-min
    for i in range(len(veri_np)):
        veri_norm[i,j]= (veri_float[i,j]-min)/maxmin_fark #deli aq

# %%
X_train= veri_norm[-20:-1,:]
Y_train= veri_np[-20:-1,-1:]

X_test= veri_norm[0:-20,:]
Y_test= veri_np[0:-20,-1:]

# %%
weight= [2000,-5,-5]
weight_yeni= [0,0,0]
epoch= 250
satir= len(X_train)
lR= 0.1
tahminlerSigmoid= []

# %%
def kayip(w, x, y):
    loss= 0
    for i in range(len(x)):
        wX= 0
        for j in range(x.shape[1]):
            wX+= w[j+1]*x[i,j]
        loss+= (w[0] + wX - y[i])**2
    return loss/x.shape[1]

# %%
def turev_w0F(w, x, y):
    turev= 0
    for i in range(satir):
        wX= 0
        for j in range(x.shape[1]):
            wX+= w[j+1]*x[i,j] 
        turev+= w[0] + wX - y[i]
    return turev/satir
    
def turev_w(w, x, y):
    turevler_w= np.zeros(x.shape[1])
    for j in range(x.shape[1]):
        turev= 0
        for i in range(len(x)):
            wX= 0
            for k in range(x.shape[1]):
                wX+= w[k+1]*x[i,k]
            turev+= (w[0] + wX - y[i])*x[i,j]
        turevler_w[j]= (turev/len(x)).item()
    return turevler_w

# %%
def sigmoid(tahmin):
    return (1.0/(1.0 + np.exp(-tahmin)))

# %%
def tahminF(w, x, y):
    
    for i in range(X_test.shape[0]):
        tahmin= 0
        wX= 0
        for j in range(x.shape[1]):
            wX+= w[j+1]*x[i,j]
        tahmin= w[0] + wX
        tahminSigmoid= sigmoid(tahmin)
        print(f'tahmin: {tahmin[0]:.0f}/{tahminSigmoid[0]}  gercek: {y[i,0]}')
    return tahminler

# %%
print('***KAYIP***')
for i in range(epoch):
    turevler_w= turev_w(weight, X_train, Y_train)
    turev_w0= turev_w0F(weight, X_train, Y_train) 
    weight_yeni[0]= weight[0] - lR*turev_w0
    for j in range(X_train.shape[1]):
        weight_yeni[j+1]= weight[j+1] - lR*turevler_w[j]

    for j in range(len(weight)):
        weight[j]= weight_yeni[j]

    maliyet= kayip(weight, X_test, Y_test)
    print(f'epoch{i}: {maliyet.item():.0f}')
# Out:
# ***KAYIP***
# epoch0: 12064
# epoch139: 12098
# epoch140: 12099
# epoch141: 12100
# epoch142: 12101
# epoch143: 12102
# epoch144: 12103
# epoch145: 12103
# epoch146: 12104
# epoch147: 12105
# epoch148: 12106
# epoch149: 12107
# epoch150: 12108
# epoch151: 12109
# epoch152: 12110
# epoch153: 12110
# epoch154: 12111
# epoch155: 12112
# epoch156: 12113
# epoch157: 12114
# epoch158: 12115
# epoch159: 12116
# epoch160: 12116
# epoch161: 12117
# epoch162: 12118
# epoch163: 12119
# epoch164: 12120
# epoch165: 12121
# epoch166: 12121
# epoch167: 12122
# epoch168: 12123
# epoch169: 12124
# epoch170: 12125
# epoch171: 12126
# epoch172: 12126
# epoch173: 12127
# epoch174: 12128
# epoch175: 12129
# epoch176: 12130
# epoch177: 12130
# epoch178: 12131
# epoch179: 12132
# epoch180: 12133
# epoch181: 12133
# epoch182: 12134
# epoch183: 12135
# epoch184: 12136
# epoch185: 12136
# epoch186: 12137
# epoch187: 12138
# epoch188: 12139
# epoch189: 12139
# epoch190: 12140
# epoch191: 12141
# epoch192: 12142
# epoch193: 12142
# epoch194: 12143
# epoch195: 12144
# epoch196: 12144
# epoch197: 12145
# epoch198: 12146
# epoch199: 12147
# epoch200: 12147
# epoch201: 12148
# epoch202: 12149
# epoch203: 12149
# epoch204: 12150
# epoch205: 12151
# epoch206: 12151
# epoch207: 12152
# epoch208: 12153
# epoch209: 12153
# epoch210: 12154
# epoch211: 12155
# epoch212: 12155
# epoch213: 12156
# epoch214: 12157
# epoch215: 12157
# epoch216: 12158
# epoch217: 12159
# epoch218: 12159
# epoch219: 12160
# epoch220: 12160
# epoch221: 12161
# epoch222: 12162
# epoch223: 12162
# epoch224: 12163
# epoch225: 12163
# epoch226: 12164
# epoch227: 12165
# epoch228: 12165
# epoch229: 12166
# epoch230: 12166
# epoch231: 12167
# epoch232: 12167
# epoch233: 12168
# epoch234: 12169
# epoch235: 12169
# epoch236: 12170
# epoch237: 12170
# epoch238: 12171
# epoch239: 12171
# epoch240: 12172
# epoch241: 12172
# epoch242: 12173
# epoch243: 12174
# epoch244: 12174
# epoch245: 12175
# epoch246: 12175
# epoch247: 12176
# epoch248: 12176
# epoch249: 12177

# %%
tahmin= tahminF(weight, X_test, Y_test)
# Out:
# tahmin: 767/1.0  gercek: 825
# tahmin: 912/1.0  gercek: 982
# tahmin: 789/1.0  gercek: 795
# tahmin: 850/1.0  gercek: 805
# tahmin: 808/1.0  gercek: 689

# %%
tahminlerSigmoid
# Out:
# []

# %%
for i in range(len(weight)):
 print(f'w{i}: {weight[i].item():.3f}')
print(weight)
# Out:
# w0: 968.016
# w1: -158.524
# w2: -192.922
# [array([968.01581057]), -158.52420659180518, -192.9220159693191]

# %% [markdown]
# ######
